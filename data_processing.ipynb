# %% [markdown]
# ## Data Processing

# %%
import pandas as pd
import numpy as np
data = pd.read_excel("data/INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls")
data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %%
data['EmpJobSatisfaction'].value_counts()
# Out:
# 4    378
# 3    354
# 2    237
# 1    231
# Name: EmpJobSatisfaction, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
# EmpNumber                       1200 non-null object
# Age                             1200 non-null int64
# Gender                          1200 non-null object
# EducationBackground             1200 non-null object
# MaritalStatus                   1200 non-null object
# EmpDepartment                   1200 non-null object
# EmpJobRole                      1200 non-null object
# BusinessTravelFrequency         1200 non-null object
# DistanceFromHome                1200 non-null int64
# EmpEducationLevel               1200 non-null int64
# EmpEnvironmentSatisfaction      1200 non-null int64
# EmpHourlyRate                   1200 non-null int64
# EmpJobInvolvement               1200 non-null int64
# EmpJobLevel                     1200 non-null int64
# EmpJobSatisfaction              1200 non-null int64
# NumCompaniesWorked              1200 non-null int64
# ...

# %%
#data["Gender"] = data["Gender"].replace(("Male","Female"),range(2))

# %%
gender_values = data["Gender"].unique()
gender_values
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
edu_bground_values = data["EducationBackground"].unique()
edu_bground_values
# Out:
# array(['Marketing', 'Life Sciences', 'Human Resources', 'Medical',
#        'Other', 'Technical Degree'], dtype=object)

# %%
marital_status_values = data["MaritalStatus"].unique()
marital_status_values
# Out:
# array(['Single', 'Married', 'Divorced'], dtype=object)

# %%
emp_department = data["EmpDepartment"].unique()
emp_department
# Out:
# array(['Sales', 'Human Resources', 'Development', 'Data Science',
#        'Research & Development', 'Finance'], dtype=object)

# %%
emp_job_roles = data["EmpJobRole"].unique()
emp_job_roles
# Out:
# array(['Sales Executive', 'Manager', 'Developer', 'Sales Representative',
#        'Human Resources', 'Senior Developer', 'Data Scientist',
#        'Senior Manager R&D', 'Laboratory Technician',
#        'Manufacturing Director', 'Research Scientist',
#        'Healthcare Representative', 'Research Director', 'Manager R&D',
#        'Finance Manager', 'Technical Architect', 'Business Analyst',
#        'Technical Lead', 'Delivery Manager'], dtype=object)

# %%
business_travel_freq = data["BusinessTravelFrequency"].unique()
business_travel_freq
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
overtime = data["OverTime"].unique()
overtime
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
attrition = data["Attrition"].unique()
attrition
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
# EmpNumber                       1200 non-null object
# Age                             1200 non-null int64
# Gender                          1200 non-null object
# EducationBackground             1200 non-null object
# MaritalStatus                   1200 non-null object
# EmpDepartment                   1200 non-null object
# EmpJobRole                      1200 non-null object
# BusinessTravelFrequency         1200 non-null object
# DistanceFromHome                1200 non-null int64
# EmpEducationLevel               1200 non-null int64
# EmpEnvironmentSatisfaction      1200 non-null int64
# EmpHourlyRate                   1200 non-null int64
# EmpJobInvolvement               1200 non-null int64
# EmpJobLevel                     1200 non-null int64
# EmpJobSatisfaction              1200 non-null int64
# NumCompaniesWorked              1200 non-null int64
# ...

# %% [markdown]
# ### Checking missing values count

# %%
data.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %% [markdown]
# ### Describing data and checking for outliers

# %%
data.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000         1200.00000
# mean     36.918333          9.165833            2.89250
# std       9.087289          8.176636            1.04412
# min      18.000000          1.000000            1.00000
# 25%      30.000000          2.000000            2.00000
# 50%      36.000000          7.000000            3.00000
# 75%      43.000000         14.000000            4.00000
# max      60.000000         29.000000            5.00000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      65.981667           2.731667
# std                      1.090599      20.211302           0.707164
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# ...

# %% [markdown]
# ### Applying One Hot Encoding for categorical features / columns

# %%
column = "Attrition"
prefix = "attrition_"
data = pd.get_dummies(data,columns = [column],prefix=prefix)

# %%
column = "OverTime"
prefix = "overtime_"
data = pd.get_dummies(data,columns = [column],prefix=prefix)

# %%
column = "BusinessTravelFrequency"
prefix = "business_travel_freq_"
data = pd.get_dummies(data,columns = [column],prefix=prefix)

# %%
column = "EmpJobRole"
prefix = "empjobrole_"
data = pd.get_dummies(data,columns = [column],prefix=prefix)

# %%
column = "EmpDepartment"
prefix = "empdep"
data = pd.get_dummies(data,columns = [column],prefix=prefix)

# %%
column = "MaritalStatus"
prefix = "maritalstatus_"
data = pd.get_dummies(data,columns = [column],prefix=prefix)

# %%
column = "EducationBackground"
prefix = "edubackground_"
data = pd.get_dummies(data,columns=[column],prefix=prefix)

# %%
column = "Gender"
prefix = "gender_"
data = pd.get_dummies(data,columns=[column],prefix=prefix)

# %%
data.head()
# Out:
#   EmpNumber  Age  DistanceFromHome  EmpEducationLevel  \
# 0  E1001000   32                10                  3
# 1  E1001006   47                14                  4
# 2  E1001007   40                 5                  4
# 3  E1001009   41                10                  4
# 4  E1001010   60                16                  4
#
#    EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  EmpJobLevel  \
# 0                           4             55                  3            2
# 1                           4             42                  3            2
# 2                           4             48                  2            3
# 3                           2             73                  2            5
# 4                           1             84                  3            2
#
#    EmpJobSatisfaction  NumCompaniesWorked  ...  maritalstatus__Married  \
# 0                   4                   1  ...                       0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 63 columns):
# EmpNumber                                  1200 non-null object
# Age                                        1200 non-null int64
# DistanceFromHome                           1200 non-null int64
# EmpEducationLevel                          1200 non-null int64
# EmpEnvironmentSatisfaction                 1200 non-null int64
# EmpHourlyRate                              1200 non-null int64
# EmpJobInvolvement                          1200 non-null int64
# EmpJobLevel                                1200 non-null int64
# EmpJobSatisfaction                         1200 non-null int64
# NumCompaniesWorked                         1200 non-null int64
# EmpLastSalaryHikePercent                   1200 non-null int64
# EmpRelationshipSatisfaction                1200 non-null int64
# TotalWorkExperienceInYears                 1200 non-null int64
# ...

# %%
data[["tmp","emp_number"]] = data.EmpNumber.str.split("E",expand=True)

# %%
data.head()
# Out:
#   EmpNumber  Age  DistanceFromHome  EmpEducationLevel  \
# 0  E1001000   32                10                  3
# 1  E1001006   47                14                  4
# 2  E1001007   40                 5                  4
# 3  E1001009   41                10                  4
# 4  E1001010   60                16                  4
#
#    EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  EmpJobLevel  \
# 0                           4             55                  3            2
# 1                           4             42                  3            2
# 2                           4             48                  2            3
# 3                           2             73                  2            5
# 4                           1             84                  3            2
#
#    EmpJobSatisfaction  NumCompaniesWorked  ...  \
# 0                   4                   1  ...
# 1                   1                   2  ...
# ...

# %%
data['emp_number'] = data['emp_number'].astype("int64")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 65 columns):
# EmpNumber                                  1200 non-null object
# Age                                        1200 non-null int64
# DistanceFromHome                           1200 non-null int64
# EmpEducationLevel                          1200 non-null int64
# EmpEnvironmentSatisfaction                 1200 non-null int64
# EmpHourlyRate                              1200 non-null int64
# EmpJobInvolvement                          1200 non-null int64
# EmpJobLevel                                1200 non-null int64
# EmpJobSatisfaction                         1200 non-null int64
# NumCompaniesWorked                         1200 non-null int64
# EmpLastSalaryHikePercent                   1200 non-null int64
# EmpRelationshipSatisfaction                1200 non-null int64
# TotalWorkExperienceInYears                 1200 non-null int64
# ...

# %% [markdown]
# ### Dropping irrelevant columns

# %%
data.drop(columns = ["tmp","EmpNumber"],inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 63 columns):
# Age                                        1200 non-null int64
# DistanceFromHome                           1200 non-null int64
# EmpEducationLevel                          1200 non-null int64
# EmpEnvironmentSatisfaction                 1200 non-null int64
# EmpHourlyRate                              1200 non-null int64
# EmpJobInvolvement                          1200 non-null int64
# EmpJobLevel                                1200 non-null int64
# EmpJobSatisfaction                         1200 non-null int64
# NumCompaniesWorked                         1200 non-null int64
# EmpLastSalaryHikePercent                   1200 non-null int64
# EmpRelationshipSatisfaction                1200 non-null int64
# TotalWorkExperienceInYears                 1200 non-null int64
# TrainingTimesLastYear                      1200 non-null int64
# ...

# %% [markdown]
# ### Exporting cleaned and formatted data to csv file

# %%
data.to_csv("../../data/processed/INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.csv")
