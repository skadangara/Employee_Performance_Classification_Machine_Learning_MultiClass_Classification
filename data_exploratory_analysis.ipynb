# %%
import pandas as pd
import numpy as np

data = pd.read_excel("data/INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
# EmpNumber                       1200 non-null object
# Age                             1200 non-null int64
# Gender                          1200 non-null object
# EducationBackground             1200 non-null object
# MaritalStatus                   1200 non-null object
# EmpDepartment                   1200 non-null object
# EmpJobRole                      1200 non-null object
# BusinessTravelFrequency         1200 non-null object
# DistanceFromHome                1200 non-null int64
# EmpEducationLevel               1200 non-null int64
# EmpEnvironmentSatisfaction      1200 non-null int64
# EmpHourlyRate                   1200 non-null int64
# EmpJobInvolvement               1200 non-null int64
# EmpJobLevel                     1200 non-null int64
# EmpJobSatisfaction              1200 non-null int64
# NumCompaniesWorked              1200 non-null int64
# ...

# %%
from collections import Counter

# %%
Counter(data.EmpNumber).most_common(20) # Non categorical
# Out:
# [('E1001000', 1),
#  ('E1001006', 1),
#  ('E1001007', 1),
#  ('E1001009', 1),
#  ('E1001010', 1),
#  ('E1001011', 1),
#  ('E1001016', 1),
#  ('E1001019', 1),
#  ('E1001020', 1),
#  ('E1001021', 1),
#  ('E1001022', 1),
#  ('E1001024', 1),
#  ('E1001025', 1),
#  ('E1001027', 1),
#  ('E1001030', 1),
#  ('E1001035', 1),
#  ('E1001038', 1),
#  ('E1001040', 1),
#  ('E1001041', 1),
#  ('E1001042', 1)]

# %%
Counter(data.Age).most_common(20) # numerical
# Out:
# [(34, 71),
#  (35, 64),
#  (36, 60),
#  (31, 57),
#  (29, 51),
#  (38, 48),
#  (32, 46),
#  (40, 46),
#  (33, 46),
#  (27, 43),
#  (30, 42),
#  (37, 41),
#  (28, 39),
#  (42, 36),
#  (45, 36),
#  (26, 33),
#  (41, 32),
#  (39, 31),
#  (44, 30),
#  (50, 28)]

# %%
Counter(data.Gender).most_common(20) # categorical
# Out:
# [('Male', 725), ('Female', 475)]

# %%
Counter(data.EducationBackground).most_common(20) # categorical
# Out:
# [('Life Sciences', 492),
#  ('Medical', 384),
#  ('Marketing', 137),
#  ('Technical Degree', 100),
#  ('Other', 66),
#  ('Human Resources', 21)]

# %%
Counter(data.MaritalStatus).most_common(10) # categorical
# Out:
# [('Married', 548), ('Single', 384), ('Divorced', 268)]

# %%
Counter(data.EmpDepartment).most_common(20) # categorical
# Out:
# [('Sales', 373),
#  ('Development', 361),
#  ('Research & Development', 343),
#  ('Human Resources', 54),
#  ('Finance', 49),
#  ('Data Science', 20)]

# %%
Counter(data.EmpJobRole).most_common(20) # categorical
# Out:
# [('Sales Executive', 270),
#  ('Developer', 236),
#  ('Manager R&D', 94),
#  ('Research Scientist', 77),
#  ('Sales Representative', 69),
#  ('Laboratory Technician', 64),
#  ('Senior Developer', 52),
#  ('Manager', 51),
#  ('Finance Manager', 49),
#  ('Human Resources', 45),
#  ('Technical Lead', 38),
#  ('Manufacturing Director', 33),
#  ('Healthcare Representative', 33),
#  ('Data Scientist', 20),
#  ('Research Director', 19),
#  ('Business Analyst', 16),
#  ('Senior Manager R&D', 15),
#  ('Delivery Manager', 12),
#  ('Technical Architect', 7)]

# %%
Counter(data.BusinessTravelFrequency).most_common(20) # categorical
# Out:
# [('Travel_Rarely', 846), ('Travel_Frequently', 222), ('Non-Travel', 132)]

# %%
Counter(data.DistanceFromHome).most_common(20) # numerical
# Out:
# [(2, 184),
#  (1, 170),
#  (8, 69),
#  (3, 67),
#  (10, 66),
#  (9, 66),
#  (7, 65),
#  (5, 54),
#  (4, 51),
#  (6, 46),
#  (16, 25),
#  (11, 25),
#  (18, 24),
#  (24, 23),
#  (29, 23),
#  (26, 22),
#  (23, 22),
#  (28, 20),
#  (25, 19),
#  (20, 19)]

# %%
Counter(data.EmpEducationLevel).most_common(50) ###  EmpEducationLevel is categorical data
# Out:
# [(3, 449), (4, 322), (2, 239), (1, 148), (5, 42)]

# %%
Counter(data.EmpEnvironmentSatisfaction).most_common(50) ## EmpEnvironmentSatisfaction is also categorical data
# Out:
# [(3, 367), (4, 361), (2, 242), (1, 230)]

# %%
Counter(data.EmpHourlyRate).most_common(20) # numerical
# Out:
# [(79, 25),
#  (66, 25),
#  (42, 24),
#  (57, 23),
#  (46, 23),
#  (96, 22),
#  (72, 22),
#  (45, 22),
#  (92, 22),
#  (48, 21),
#  (84, 21),
#  (43, 21),
#  (52, 21),
#  (94, 21),
#  (87, 21),
#  (73, 20),
#  (54, 20),
#  (86, 20),
#  (98, 20),
#  (32, 19)]

# %%
Counter(data.EmpJobInvolvement).most_common(50) # EmpJobInvolvement - categorical data
# Out:
# [(3, 724), (2, 294), (4, 112), (1, 70)]

# %%
Counter(data.EmpJobLevel).most_common(50) # EmpJobLevel - categorical data
# Out:
# [(2, 441), (1, 440), (3, 173), (4, 90), (5, 56)]

# %%
Counter(data.EmpJobSatisfaction).most_common(50) # EmpJobSatisfaction - categorical data
# Out:
# [(4, 378), (3, 354), (2, 237), (1, 231)]

# %%
Counter(data.NumCompaniesWorked).most_common(50) # numerical
# Out:
# [(1, 433),
#  (0, 156),
#  (3, 133),
#  (2, 123),
#  (4, 107),
#  (7, 60),
#  (6, 56),
#  (5, 53),
#  (8, 40),
#  (9, 39)]

# %%
Counter(data.OverTime).most_common(20) # categorical
# Out:
# [('No', 847), ('Yes', 353)]

# %%
Counter(data.EmpLastSalaryHikePercent).most_common(50) # numerical
# Out:
# [(14, 172),
#  (11, 169),
#  (13, 168),
#  (12, 155),
#  (15, 82),
#  (18, 73),
#  (16, 68),
#  (17, 67),
#  (19, 63),
#  (20, 50),
#  (22, 47),
#  (21, 34),
#  (23, 21),
#  (24, 18),
#  (25, 13)]

# %%
Counter(data.EmpRelationshipSatisfaction).most_common(50) # EmpRelationshipSatisfaction - categorical data
# Out:
# [(3, 379), (4, 355), (2, 247), (1, 219)]

# %%
Counter(data.TotalWorkExperienceInYears).most_common(20) # numerical
# Out:
# [(10, 159),
#  (6, 105),
#  (8, 85),
#  (9, 77),
#  (5, 71),
#  (1, 65),
#  (7, 61),
#  (4, 51),
#  (12, 37),
#  (3, 34),
#  (15, 34),
#  (11, 33),
#  (13, 33),
#  (16, 32),
#  (21, 28),
#  (2, 26),
#  (14, 26),
#  (20, 25),
#  (17, 24),
#  (18, 21)]

# %%
Counter(data.TrainingTimesLastYear).most_common(150) # TrainingTimesLastYear - categorical
# Out:
# [(2, 445), (3, 413), (4, 98), (5, 98), (1, 56), (6, 46), (0, 44)]

# %%
Counter(data.EmpWorkLifeBalance).most_common(50) # EmpWorkLifeBalance - categorical
# Out:
# [(3, 727), (2, 294), (4, 115), (1, 64)]

# %%
Counter(data.ExperienceYearsAtThisCompany).most_common(20) # numerical
# Out:
# [(5, 152),
#  (1, 138),
#  (2, 107),
#  (3, 105),
#  (10, 100),
#  (4, 88),
#  (7, 73),
#  (9, 66),
#  (6, 66),
#  (8, 63),
#  (0, 36),
#  (11, 27),
#  (20, 21),
#  (13, 18),
#  (15, 17),
#  (21, 14),
#  (12, 14),
#  (14, 14),
#  (22, 12),
#  (18, 11)]

# %%
Counter(data.ExperienceYearsInCurrentRole).most_common(20) # numerical
# Out:
# [(2, 303),
#  (0, 190),
#  (7, 176),
#  (3, 107),
#  (4, 92),
#  (8, 78),
#  (9, 63),
#  (1, 46),
#  (6, 30),
#  (5, 29),
#  (10, 25),
#  (11, 18),
#  (13, 10),
#  (14, 10),
#  (12, 7),
#  (16, 7),
#  (15, 4),
#  (17, 3),
#  (18, 2)]

# %%
Counter(data.YearsSinceLastPromotion).most_common(50) # numerical
# Out:
# [(0, 469),
#  (1, 297),
#  (2, 127),
#  (7, 62),
#  (4, 53),
#  (3, 45),
#  (5, 35),
#  (6, 24),
#  (11, 23),
#  (9, 16),
#  (8, 11),
#  (15, 11),
#  (12, 9),
#  (13, 8),
#  (14, 5),
#  (10, 5)]

# %%
Counter(data.YearsWithCurrManager).most_common(50) # numerical
# Out:
# [(2, 281),
#  (0, 215),
#  (7, 176),
#  (3, 103),
#  (8, 87),
#  (4, 85),
#  (1, 67),
#  (9, 53),
#  (6, 28),
#  (5, 26),
#  (10, 22),
#  (11, 20),
#  (12, 14),
#  (13, 10),
#  (17, 6),
#  (15, 3),
#  (16, 2),
#  (14, 2)]

# %%
Counter(data.Attrition).most_common(20) # categorical
# Out:
# [('No', 1022), ('Yes', 178)]

# %%
Counter(data.PerformanceRating).most_common(20) # categorical
# Out:
# [(3, 874), (2, 194), (4, 132)]

# %% [markdown]
# ### Box plotting numerical values

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#data.info()

# %%
box_plot_data = [data["Age"],data["DistanceFromHome"],data["EmpHourlyRate"],
                data["NumCompaniesWorked"],data["EmpLastSalaryHikePercent"],
                data["TotalWorkExperienceInYears"],data["ExperienceYearsAtThisCompany"],data["ExperienceYearsInCurrentRole"],
                 data["YearsSinceLastPromotion"],data['YearsWithCurrManager']
                ]
plt.figure(figsize = [14,7])
_ = plt.boxplot(box_plot_data,patch_artist=True,labels=["Age","DistanceFromHome","EmpHourlyRate",
                                                    "NumCompaniesWorked","EmpLastSalaryHikePercent",
                                                    "TotalWorkExperienceInYears",
                                                    "ExperienceYearsAtThisCompany","ExperienceYearsInCurrentRole",
                                                        "YearsSinceLastPromotion",'YearsWithCurrManager'
                                                   ])

# %%
data["TotalWorkExperienceInYears"].max()
# Out:
# 40

# %%
data["ExperienceYearsAtThisCompany"].max()
# Out:
# 40

# %%
data[data.ExperienceYearsAtThisCompany > 37].count()
# Out:
# EmpNumber                       1
# Age                             1
# Gender                          1
# EducationBackground             1
# MaritalStatus                   1
# EmpDepartment                   1
# EmpJobRole                      1
# BusinessTravelFrequency         1
# DistanceFromHome                1
# EmpEducationLevel               1
# EmpEnvironmentSatisfaction      1
# EmpHourlyRate                   1
# EmpJobInvolvement               1
# EmpJobLevel                     1
# EmpJobSatisfaction              1
# NumCompaniesWorked              1
# OverTime                        1
# EmpLastSalaryHikePercent        1
# EmpRelationshipSatisfaction     1
# TotalWorkExperienceInYears      1
# TrainingTimesLastYear           1
# EmpWorkLifeBalance              1
# ExperienceYearsAtThisCompany    1
# ExperienceYearsInCurrentRole    1
# YearsSinceLastPromotion         1
# YearsWithCurrManager            1
# Attrition                       1
# ...

# %%
cat_columns = data.dtypes[data.dtypes == "object"]
cat_columns
# Out:
# EmpNumber                  object
# Gender                     object
# EducationBackground        object
# MaritalStatus              object
# EmpDepartment              object
# EmpJobRole                 object
# BusinessTravelFrequency    object
# OverTime                   object
# Attrition                  object
# dtype: object

# %%
import seaborn as sns

# %matplotlib inline

for i in cat_columns.index:
    if i == 'EmpNumber':
        continue
    print(i+"  PerformanceRating Count Plot")
    plt.figure(figsize=(14, 7))
    #sns.catplot(x=i,hue="PerformanceRating",kind="count",palette="pastel",edgecolor=".6",data=data,height=14, aspect=2)
    sns.countplot(x=i,hue="PerformanceRating",palette="pastel",data=data)
    plt.show()
# Out:
# Gender  PerformanceRating Count Plot
# EducationBackground  PerformanceRating Count Plot
# MaritalStatus  PerformanceRating Count Plot
# EmpDepartment  PerformanceRating Count Plot
# EmpJobRole  PerformanceRating Count Plot
# BusinessTravelFrequency  PerformanceRating Count Plot
# OverTime  PerformanceRating Count Plot
# Attrition  PerformanceRating Count Plot

# %% [markdown]
# ### Selecting 5 best features from categorical feature

# %%
from sklearn.feature_selection import SelectKBest 
from sklearn.feature_selection import chi2

#importing one hot encoded data

data = pd.read_csv("../../data/processed/INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.csv")

X = data.drop(['Age', 'DistanceFromHome', 'EmpHourlyRate', 'NumCompaniesWorked',
       'EmpLastSalaryHikePercent', 'TotalWorkExperienceInYears',
       'ExperienceYearsAtThisCompany', 'ExperienceYearsInCurrentRole',
       'YearsSinceLastPromotion', 'YearsWithCurrManager', 'PerformanceRating','emp_number',
               'empjobrole__Finance Manager'],axis=1) #data.iloc[:,:-1]
y = data.PerformanceRating
#X = X.astype('int64')
best_features = SelectKBest(chi2, k = 10) 
fit = best_features.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
feature_scores = pd.concat([dfcolumns,dfscores],axis=1)
feature_scores.columns = ['features','score']
print(feature_scores.nlargest(10,'score'))
# Out:
#                           features       score
# 2       EmpEnvironmentSatisfaction  110.691319
# 35              empdep_Development   42.136613
# 19           empjobrole__Developer   32.352231
# 39                    empdep_Sales   14.279220
# 28     empjobrole__Sales Executive   11.476588
# 12                   overtime__Yes    7.963530
# 36                  empdep_Finance    7.589899
# 27  empjobrole__Research Scientist    7.087146
# 23             empjobrole__Manager    6.931444
# 47            edubackground__Other    6.830992

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 64 columns):
# Unnamed: 0                                 1200 non-null int64
# Age                                        1200 non-null int64
# DistanceFromHome                           1200 non-null int64
# EmpEducationLevel                          1200 non-null int64
# EmpEnvironmentSatisfaction                 1200 non-null int64
# EmpHourlyRate                              1200 non-null int64
# EmpJobInvolvement                          1200 non-null int64
# EmpJobLevel                                1200 non-null int64
# EmpJobSatisfaction                         1200 non-null int64
# NumCompaniesWorked                         1200 non-null int64
# EmpLastSalaryHikePercent                   1200 non-null int64
# EmpRelationshipSatisfaction                1200 non-null int64
# TotalWorkExperienceInYears                 1200 non-null int64
# ...

# %%
X = data.iloc[:,[1,2,5,9,10,12,15,16,17,18,19]]
y = data.PerformanceRating

# %%
X.columns
# Out:
# Index(['Age', 'DistanceFromHome', 'EmpHourlyRate', 'NumCompaniesWorked',
#        'EmpLastSalaryHikePercent', 'TotalWorkExperienceInYears',
#        'ExperienceYearsAtThisCompany', 'ExperienceYearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'PerformanceRating'],
#       dtype='object')

# %%
### Plotting heat map for identifying highly correlated numerical features with Target variable Performance Rating.

# %%
corrmat = X.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [raw]
# ### Below are the features selected from correlation matrix of Numerical Features
#  ## Features
#  Age
#  DistanceFromHome
#  EmpHourlyRate
#  NumCompaniesWorked
#  EmpLastSalaryHikePercent

# %% [raw]
# ## Features From Chi2 Selection with score
# 2       EmpEnvironmentSatisfaction  110.691319
# 35              empdep_Development   42.136613
# 19           empjobrole__Developer   32.352231
# 39                    empdep_Sales   14.279220
# 28     empjobrole__Sales Executive   11.476588
# 12                   overtime__Yes    7.963530
# 36                  empdep_Finance    7.589899
# 27  empjobrole__Research Scientist    7.087146
# 23             empjobrole__Manager    6.931444
# 47            edubackground__Other    6.830992
